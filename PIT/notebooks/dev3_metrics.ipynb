# %% [markdown]
# # Métricas e Visualizações (Dev 3)
#
# Este notebook é dedicado ao Dev 3 para explorar os resultados do modelo,
# gerar gráficos de apoio para o pitch e montar o resumo executivo.

# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "pandas", "matplotlib", "seaborn", "scikit-learn"], check=True)
# Out:
# CompletedProcess(args=['c:\\Users\\Murilo\\Documents\\Hackathon\\.venv\\Scripts\\python.exe', '-m', 'pip', 'install', 'pandas', 'matplotlib', 'seaborn', 'scikit-learn'], returncode=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import sys
sys.path.append('../src')

# Carregar as métricas geradas pelo Dev 1 e 2
with open('../outputs/metricas.json', 'r') as f:
    metricas = json.load(f)

print("Métricas carregadas:", metricas)
# Out:
# Métricas carregadas: {'ROC_AUC': 0.7842263077657889, 'KS': 0.43636965374228587, 'PR_AUC': 0.3305622404263398, 'Recall_at_threshold': 0.4274284952330155, 'threshold_usado': 0.5}
